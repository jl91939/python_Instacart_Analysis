# %% [markdown]
# # Importing Libraries.

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Setting Path.

# %%
path = r'C:\Users\Chaot\02-2024 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\Chaot\\02-2024 Instacart Basket Analysis'

# %% [markdown]
# # Import Dataframes.

# %%
df_orders_prior = pd.read_pickle(os.path.join(path, '02 - Data', 'Prepared Data', 'orders_products_combined.pkl'))
df_prod = pd.read_csv(os.path.join(path, '02 - Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
#Checking DF.
df_orders_prior
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0                    0           0   2539329        1             1
# 1                    0           0   2539329        1             1
# 2                    0           0   2539329        1             1
# 3                    0           0   2539329        1             1
# 4                    0           0   2539329        1             1
# ...                ...         ...       ...      ...           ...
# 32434484       3421081     3421081   2977660   206209            13
# 32434485       3421081     3421081   2977660   206209            13
# 32434486       3421081     3421081   2977660   206209            13
# 32434487       3421081     3421081   2977660   206209            13
# 32434488       3421081     3421081   2977660   206209            13
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                          2                  8                     NaN
# ...

# %%
#Checking DF.
df_prod
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %% [markdown]
# # Merging Dataframes.

# %%
#Merging the Dataframe on Product ID
df_merge_large = df_orders_prior.merge(df_prod, on = 'product_id', indicator= 'indicator2')

# %%
#Checking DF.
df_merge_large
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0                    0             0   2539329        1             1
# 1                    1             1   2398795        1             2
# 2                    2             2    473747        1             3
# 3                    3             3   2254736        1             4
# 4                    4             4    431534        1             5
# ...                ...           ...       ...      ...           ...
# 32404854       3360493       3360493   1320836   202557            17
# 32404855       3360494       3360494     31526   202557            18
# 32404856       3376038       3376038    758936   203436             1
# 32404857       3376039       3376039   2745165   203436             2
# 32404858       3408036       3408036   3093936   205420             1
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# ...

# %% [markdown]
# Indicator 2 is showing Both - this is the new flag to show that it was combined (order_products_combined + products_checked)

# %% [markdown]
# # Exporting Dataframe as PKL.

# %%
df_merge_large.to_pickle(os.path.join(path, '02 - Data', 'Prepared Data', 'order_products_merged.pkl'))
